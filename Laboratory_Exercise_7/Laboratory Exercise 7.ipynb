# %% [markdown]
# # Exercise 1

# %%
import sys
import os
from importlib import reload 
try:
    notebook_dir = os.path.dirname(os.path.abspath(__file__)) 
except NameError:
    notebook_dir = os.getcwd() 

pyke_installation_dir = os.path.join(notebook_dir, "pyke-1.1.1")
family_relations_example_path = os.path.join(pyke_installation_dir, "examples", "family_relations")

print(f"Notebook directory: {notebook_dir}")
print(f"PyKE installation directory (expected): {pyke_installation_dir}")
print(f"Family relations example path: {family_relations_example_path}")

if not os.path.isdir(family_relations_example_path):
    print(f"ERROR: The path '{family_relations_example_path}' does not exist or is not a directory.")
    print("Please check your folder structure and the 'pyke_installation_dir' variable.")
else:
    print(f"SUCCESS: Found family_relations directory at: {family_relations_example_path}")

    if family_relations_example_path not in sys.path:
        sys.path.append(family_relations_example_path)
        print(f"Added to sys.path: {family_relations_example_path}")

try:
    from pyke import knowledge_engine, goal
    print("Successfully imported PyKE components (knowledge_engine, goal). PyKE is likely installed correctly.")
except ImportError as e:
    print(f"ERROR importing PyKE: {e}")
    print("PyKE might not be installed correctly in the environment Jupyter is using.")
    print("Please ensure you ran 'python setup.py install' from the pyke-1.1.1 directory in your terminal.")
# Out:
# Notebook directory: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7
# PyKE installation directory (expected): c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1
# Family relations example path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\examples\family_relations
# SUCCESS: Found family_relations directory at: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\examples\family_relations
# Added to sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\examples\family_relations
# Successfully imported PyKE components (knowledge_engine, goal). PyKE is likely installed correctly.

# %%
# Task 1.b

from importlib import reload
import driver 

print("Reloading DRIVER.PY with modifications for Task 1.b...")
reload(driver) 
print("-" * 40)

print("--- Testing Task 1.b: Relationship between 'bruce' and 'mitch' ---")
driver.fc_test('bruce', 'mitch') 
print("-" * 40)

print("--- Testing Task 1.b: Relationship between 'norma' and 'allen' ---")
driver.fc_test('norma', 'allen')
print("-" * 40)

print("--- Testing Task 1.b: Relationship between 'bruce' and 'non_existent_person' ---")
driver.fc_test('bruce', 'non_existent_person')
print("-" * 40)
# Out:
# Reloading DRIVER.PY with modifications for Task 1.b...
# ----------------------------------------
# --- Testing Task 1.b: Relationship between 'bruce' and 'mitch' ---
# Activating forward-chaining rules from 'fc_example' for fc_test (bruce, mitch)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Doing proof for the relationship between bruce and mitch:
# bruce and mitch are related as: ('1st', 'cousins')
#
# done with fc_test
# Proof time for this pair: 0.01s
# ----------------------------------------
# --- Testing Task 1.b: Relationship between 'norma' and 'allen' ---
# Activating forward-chaining rules from 'fc_example' for fc_test (norma, allen)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.13s
#
# Doing proof for the relationship between norma and allen:
# norma and allen are related as: ('daughter', 'father')
#
# done with fc_test
# Proof time for this pair: 0.00s
# ----------------------------------------
# --- Testing Task 1.b: Relationship between 'bruce' and 'non_existent_person' ---
# Activating forward-chaining rules from 'fc_example' for fc_test (bruce, non_existent_person)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Doing proof for the relationship between bruce and non_existent_person:
# No specific relationship found by 'how_related' between bruce and non_existent_person.
#
# done with fc_test
# Proof time for this pair: 0.00s
# ----------------------------------------

# %%
# Task 1.c (Finding brothers)

from importlib import reload
import driver 

print("Reloading DRIVER.PY and KRB files for Task 1.c...")
reload(driver) 
print("-" * 40)

print("--- Testing Task 1.c: Finding who 'bruce' is a brother to ---")
# Bruce's parents: thomas, norma
# Bruce's male siblings (sons of thomas, norma): fred_a, tim
# Bruce's female siblings (daughters of thomas, norma): vicki, jill
driver.find_brothers_test('bruce') 
print("-" * 40)

print("--- Testing Task 1.c: Finding who 'john_w' is a brother to ---")
# john_w's parents: allen, ismay
# john_w's male siblings: bill, chuck_w
# john_w's female siblings: norma
driver.find_brothers_test('john_w')
print("-" * 40)

print("--- Testing Task 1.c: Finding who 'norma' (female) is a brother to ---")
driver.find_brothers_test('norma')
print("-" * 40)
# Out:
# Reloading DRIVER.PY and KRB files for Task 1.c...
# ----------------------------------------
# --- Testing Task 1.c: Finding who 'bruce' is a brother to ---
#
# Activating forward-chaining rules from 'fc_example' for find_brothers_test (bruce)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Finding siblings for whom 'bruce' is a brother:
# - bruce is a brother to: fred_a
# - bruce is a brother to: tim
# - bruce is a brother to: vicki
# - bruce is a brother to: jill
#
# done with find_brothers_test
# Proof time for this query: 0.00s
# ----------------------------------------
# --- Testing Task 1.c: Finding who 'john_w' is a brother to ---
#
# Activating forward-chaining rules from 'fc_example' for find_brothers_test (john_w)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Finding siblings for whom 'john_w' is a brother:
# - john_w is a brother to: bill
# - john_w is a brother to: chuck_w
# - john_w is a brother to: norma
#
# done with find_brothers_test
# Proof time for this query: 0.00s
# ----------------------------------------
# --- Testing Task 1.c: Finding who 'norma' (female) is a brother to ---
#
# Activating forward-chaining rules from 'fc_example' for find_brothers_test (norma)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.15s
#
# Finding siblings for whom 'norma' is a brother:
# No one found for whom 'norma' is a brother (either 'norma' is not male, has no siblings defined by rules, or the person does not exist).
#
# done with find_brothers_test
# Proof time for this query: 0.00s
# ----------------------------------------

# %%
# Task 1.d (Finding sisters)
from importlib import reload
import driver 

print("Reloading DRIVER.PY and (forcing recompile of) fc_example.KRB for Task 1.d...")
# Forceful reload after kernel restart and manual compiled_krb creation
if 'driver' in sys.modules:
    del sys.modules['driver']
import driver # Fresh import

print("-" * 40)

print("--- Testing Task 1.d: Finding who 'norma' is a sister to ---")
driver.find_sisters_test('norma')
print("-" * 40)

print("--- Testing Task 1.d: Finding who 'vicki' is a sister to ---")
driver.find_sisters_test('vicki')
print("-" * 40)

print("--- Testing Task 1.d: Finding who 'bruce' (male) is a sister to ---")
driver.find_sisters_test('bruce')
print("-" * 40)
# Out:
# Reloading DRIVER.PY and (forcing recompile of) fc_example.KRB for Task 1.d...
# ----------------------------------------
# --- Testing Task 1.d: Finding who 'norma' is a sister to ---
#
# Activating forward-chaining rules from 'fc_example' for find_sisters_test (norma)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Finding siblings for whom 'norma' is a sister:
# No one found for whom 'norma' is a sister (either 'norma' is not female, has no siblings defined by rules, or the person does not exist).
#
# done with find_sisters_test
# Proof time for this query: 0.00s
# ----------------------------------------
# --- Testing Task 1.d: Finding who 'vicki' is a sister to ---
#
# Activating forward-chaining rules from 'fc_example' for find_sisters_test (vicki)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.15s
#
# Finding siblings for whom 'vicki' is a sister:
# No one found for whom 'vicki' is a sister (either 'vicki' is not female, has no siblings defined by rules, or the person does not exist).
#
# done with find_sisters_test
# Proof time for this query: 0.00s
# ----------------------------------------
# --- Testing Task 1.d: Finding who 'bruce' (male) is a sister to ---
#
# Activating forward-chaining rules from 'fc_example' for find_sisters_test (bruce)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Finding siblings for whom 'bruce' is a sister:
# No one found for whom 'bruce' is a sister (either 'bruce' is not female, has no siblings defined by rules, or the person does not exist).
#
# done with find_sisters_test
# Proof time for this query: 0.00s
# ----------------------------------------

# %%
# Task 1.e (Finding all siblings - brother or sister)

from importlib import reload
import driver 

print("Reloading DRIVER.PY and fc_example.KRB for Task 1.e...")
reload(driver) 
print("-" * 40)

print("--- Testing Task 1.e: Finding all siblings for 'bruce' ---")
# Expected: Bruce is a brother to fred_a, tim, vicki, jill
driver.find_all_siblings_for_person_test('bruce')
print("-" * 40)

print("--- Testing Task 1.e: Finding all siblings for 'norma' ---")
# Expected: Norma is a sister to john_w, bill, chuck_w
driver.find_all_siblings_for_person_test('norma')
print("-" * 40)

print("--- Testing Task 1.e: Finding all siblings for 'mitch' ---")
# Mitch (son of john_w, cleo). john_w also has daughters jonni, lorri with cleo.
# So, Mitch should be a brother to jonni and lorri.
driver.find_all_siblings_for_person_test('mitch')
print("-" * 40)

print("--- Testing Task 1.e: Finding all siblings for 'non_existent' ---")
driver.find_all_siblings_for_person_test('non_existent')
print("-" * 40)
# Out:
# Reloading DRIVER.PY and fc_example.KRB for Task 1.e...
# ----------------------------------------
# --- Testing Task 1.e: Finding all siblings for 'bruce' ---
#
# Activating forward-chaining rules from 'fc_example' for find_all_siblings_for_person_test (bruce)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Finding all persons for whom 'bruce' is a sibling (brother or sister):
#   Checking if 'bruce' is a brother to anyone...
#   - bruce is a BROTHER to: fred_a
#   - bruce is a BROTHER to: tim
#   - bruce is a BROTHER to: vicki
#   - bruce is a BROTHER to: jill
#   Checking if 'bruce' is a sister to anyone...
#
# done with find_all_siblings_for_person_test
# ----------------------------------------
# --- Testing Task 1.e: Finding all siblings for 'norma' ---
#
# Activating forward-chaining rules from 'fc_example' for find_all_siblings_for_person_test (norma)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Finding all persons for whom 'norma' is a sibling (brother or sister):
#   Checking if 'norma' is a brother to anyone...
#   Checking if 'norma' is a sister to anyone...
# 'norma' was not found to be a brother or a sister to anyone based on the defined rules.
#
# done with find_all_siblings_for_person_test
# ----------------------------------------
# --- Testing Task 1.e: Finding all siblings for 'mitch' ---
#
# Activating forward-chaining rules from 'fc_example' for find_all_siblings_for_person_test (mitch)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Finding all persons for whom 'mitch' is a sibling (brother or sister):
#   Checking if 'mitch' is a brother to anyone...
#   - mitch is a BROTHER to: jonni
#   - mitch is a BROTHER to: lorri
#   Checking if 'mitch' is a sister to anyone...
#
# done with find_all_siblings_for_person_test
# ----------------------------------------
# --- Testing Task 1.e: Finding all siblings for 'non_existent' ---
#
# Activating forward-chaining rules from 'fc_example' for find_all_siblings_for_person_test (non_existent)...
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# Activation time: 0.14s
#
# Finding all persons for whom 'non_existent' is a sibling (brother or sister):
#   Checking if 'non_existent' is a brother to anyone...
#   Checking if 'non_existent' is a sister to anyone...
# 'non_existent' was not found to be a brother or a sister to anyone based on the defined rules.
#
# done with find_all_siblings_for_person_test
# ----------------------------------------

# %%
# Task 1.f (Check if two specific persons are siblings)

from importlib import reload
import driver 

print("Reloading DRIVER.PY and fc_example.KRB for Task 1.f...")
reload(driver) 
print("-" * 40)

print("--- Testing Task 1.f: Check siblings 'bruce' and 'fred_a' ---")
# Expected: bruce is a BROTHER to fred_a (or fred_a is brother to bruce)
driver.check_if_specific_siblings_test('bruce', 'fred_a')
print("-" * 40)

print("--- Testing Task 1.f: Check siblings 'norma' and 'john_w' ---")
# Expected: norma is a SISTER to john_w (or john_w is brother to norma)
driver.check_if_specific_siblings_test('norma', 'john_w')
print("-" * 40)

print("--- Testing Task 1.f: Check siblings 'vicki' and 'jill' ---")
# Expected: vicki is a SISTER to jill (or jill is sister to vicki)
driver.check_if_specific_siblings_test('vicki', 'jill')
print("-" * 40)

print("--- Testing Task 1.f: Check non-siblings 'bruce' and 'allen' ---")
# Expected: No output (bruce is son of allen, not sibling)
driver.check_if_specific_siblings_test('bruce', 'allen')
print("-" * 40)

print("--- Testing Task 1.f: Check with non-existent 'bruce' and 'ghost' ---")
# Expected: No output
driver.check_if_specific_siblings_test('bruce', 'ghost')
print("-" * 40)
# Out:
# Reloading DRIVER.PY and fc_example.KRB for Task 1.f...
# ----------------------------------------
# --- Testing Task 1.f: Check siblings 'bruce' and 'fred_a' ---
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# bruce is a BROTHER to fred_a.
# ----------------------------------------
# --- Testing Task 1.f: Check siblings 'norma' and 'john_w' ---
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# john_w is a BROTHER to norma.
# ----------------------------------------
# --- Testing Task 1.f: Check siblings 'vicki' and 'jill' ---
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# ----------------------------------------
# --- Testing Task 1.f: Check non-siblings 'bruce' and 'allen' ---
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# ----------------------------------------
# --- Testing Task 1.f: Check with non-existent 'bruce' and 'ghost' ---
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
# ----------------------------------------

# %%
# Task 1.g (Finding grandparents)

from importlib import reload
import driver 

print("Reloading DRIVER.PY and fc_example.KRB for Task 1.g...")
reload(driver) 
print("-" * 40)

print("--- Testing Task 1.g: Finding grandparents of 'bruce' ---")
# bruce -> parents: thomas, norma
# thomas -> parents: frederik, mary (grandparents of bruce)
# norma -> parents: allen, ismay (grandparents of bruce)
driver.find_grandparents_test('bruce')
print("-" * 40)

print("--- Testing Task 1.g: Finding grandparents of 'mitch' ---")
# mitch -> parents: john_w, cleo
# john_w -> parents: allen, ismay (grandparents of mitch)
# cleo -> (parents not in this kfb for cleo, so only paternal GPs will be found)
driver.find_grandparents_test('mitch')
print("-" * 40)

print("--- Testing Task 1.g: Finding grandparents of 'allen' (has no grandparents in kfb) ---")
driver.find_grandparents_test('allen')
print("-" * 40)
# Out:
# Reloading DRIVER.PY and fc_example.KRB for Task 1.g...
# ----------------------------------------
# --- Testing Task 1.g: Finding grandparents of 'bruce' ---
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
#
# Finding grandparents of 'bruce':
# - frederik is a grandparent of bruce.
# - mary is a grandparent of bruce.
# - allen is a grandparent of bruce.
# - ismay is a grandparent of bruce.
#
# done with find_grandparents_test
# Proof time for this query: 0.00s
# ----------------------------------------
# --- Testing Task 1.g: Finding grandparents of 'mitch' ---
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
#
# Finding grandparents of 'mitch':
# - allen is a grandparent of mitch.
# - ismay is a grandparent of mitch.
#
# done with find_grandparents_test
# Proof time for this query: 0.00s
# ----------------------------------------
# --- Testing Task 1.g: Finding grandparents of 'allen' (has no grandparents in kfb) ---
# DEBUG infer_female: Found daughter_of for helen
# DEBUG infer_female: Found daughter_of for roberta
# DEBUG infer_female: Found daughter_of for gladis
# DEBUG infer_female: Found daughter_of for sarah_r
# DEBUG infer_female: Found daughter_of for alice
# DEBUG infer_female: Found daughter_of for kathleen
# DEBUG infer_female: Found daughter_of for darleen
# DEBUG infer_female: Found daughter_of for birdie
# DEBUG infer_female: Found daughter_of for donna
# DEBUG infer_female: Found daughter_of for shirley
# DEBUG infer_female: Found daughter_of for sarah_a
# DEBUG infer_female: Found daughter_of for heidi_m
# DEBUG infer_female: Found daughter_of for holly
# DEBUG infer_female: Found daughter_of for anne
# DEBUG infer_female: Found daughter_of for carol
# DEBUG infer_female: Found daughter_of for nanette
# DEBUG infer_female: Found daughter_of for sue
# DEBUG infer_female: Found daughter_of for marilyn
# DEBUG infer_female: Found daughter_of for m_helen
# DEBUG infer_female: Found daughter_of for beverly
# DEBUG infer_female: Found daughter_of for dianna
# DEBUG infer_female: Found daughter_of for teresa
# DEBUG infer_female: Found daughter_of for katrina
# DEBUG infer_female: Found daughter_of for samantha
# DEBUG infer_female: Found daughter_of for tiffany
# DEBUG infer_female: Found daughter_of for anita
# DEBUG infer_female: Found daughter_of for debbie
# DEBUG infer_female: Found daughter_of for rachael
# DEBUG infer_female: Found daughter_of for heidi_j
# DEBUG infer_female: Found daughter_of for sarah_k
# DEBUG infer_female: Found daughter_of for dominique
# DEBUG infer_female: Found daughter_of for barbara
# DEBUG infer_female: Found daughter_of for mary_k
# DEBUG infer_female: Found daughter_of for jackie
# DEBUG infer_female: Found daughter_of for andrea
# DEBUG infer_female: Found daughter_of for amanda
# DEBUG infer_female: Found daughter_of for tammy
# DEBUG infer_female: Found daughter_of for crystal
# DEBUG infer_female: Found daughter_of for joyce
# DEBUG infer_female: Found daughter_of for phyllis
# DEBUG infer_female: Found daughter_of for dee
# DEBUG infer_female: Found daughter_of for norma
# DEBUG infer_female: Found daughter_of for jonni
# DEBUG infer_female: Found daughter_of for lorri
# DEBUG infer_female: Found daughter_of for charli
# DEBUG infer_female: Found daughter_of for jeri
# DEBUG infer_female: Found daughter_of for annette
# DEBUG infer_female: Found daughter_of for helen_w
# DEBUG infer_female: Found daughter_of for mary_w
# DEBUG infer_female: Found daughter_of for jamie
# DEBUG infer_female: Found daughter_of for jessica
# DEBUG infer_female: Found daughter_of for bridget
# DEBUG infer_female: Found daughter_of for victoria
# DEBUG infer_female: Found daughter_of for vicki
# DEBUG infer_female: Found daughter_of for jill
#
# Finding grandparents of 'allen':
# No grandparents found for 'allen' based on the rules.
#
# done with find_grandparents_test
# Proof time for this query: 0.00s
# ----------------------------------------

# %% [markdown]
# # Exercise 2

# %%
import sys
import os
from importlib import reload

try:
    notebook_dir = os.path.dirname(os.path.abspath(__file__)) 
except NameError:
    notebook_dir = os.getcwd() 

vremenski_ekspert_path = os.path.join(notebook_dir, "vremenski_ekspert")
print(f"Putanja do 'vremenski_ekspert' direktorijuma: {vremenski_ekspert_path}")

if not os.path.isdir(vremenski_ekspert_path):
    print(f"GREŠKA: Direktorijum '{vremenski_ekspert_path}' nije pronađen.")
else:
    print(f"SUCCESS: Direktorijum '{vremenski_ekspert_path}' pronađen.")
    if vremenski_ekspert_path not in sys.path:
        sys.path.append(vremenski_ekspert_path)
        print(f"Dodato u sys.path: {vremenski_ekspert_path}")

    try:
        # Force reload of driver
        if 'vrijeme_driver' in sys.modules:
            del sys.modules['vrijeme_driver']
        import vrijeme_driver
        print("Modul 'vrijeme_driver.py' uspješno importovan/reloadovan.")
        print("-" * 50)
        
        # --- Testiranje različitih scenarija ---
        # Sada proslijeđujemo putanju do direktorijuma znanja funkciji testiraj_sistem
        
        # Scenario 1: Pada kiša, puše vjetar
        vrijeme_driver.testiraj_sistem(vremenski_ekspert_path, pada_kisa_cinjenica=True, puse_vjetar_cinjenica=True)
        print("-" * 50)
        
        # Scenario 2: Pada kiša, ne puše vjetar
        vrijeme_driver.testiraj_sistem(vremenski_ekspert_path, pada_kisa_cinjenica=True, puse_vjetar_cinjenica=False)
        print("-" * 50)
        
        # Scenario 3: Ne pada kiša, ne puše vjetar
        vrijeme_driver.testiraj_sistem(vremenski_ekspert_path, pada_kisa_cinjenica=False, puse_vjetar_cinjenica=False)
        print("-" * 50)
        
        # Dodatni Scenario 4: Ne pada kiša, puše vjetar
        vrijeme_driver.testiraj_sistem(vremenski_ekspert_path, pada_kisa_cinjenica=False, puse_vjetar_cinjenica=True)
        print("-" * 50)

    except ImportError as e:
        print(f"GREŠKA prilikom importovanja 'vrijeme_driver.py': {e}")
    except Exception as e:
        print(f"Došlo je do neočekivane greške: {e}")
        import traceback
        traceback.print_exc()
# Out:
# Putanja do 'vremenski_ekspert' direktorijuma: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert
# SUCCESS: Direktorijum 'c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert' pronađen.
# Dodato u sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert
# Modul 'vrijeme_driver.py' uspješno importovan/reloadovan.
# --------------------------------------------------
# Preporuka: Greška engine-a (nije inicijalizovan)
# --------------------------------------------------
# Preporuka: Greška engine-a (nije inicijalizovan)
# --------------------------------------------------
# Preporuka: Greška engine-a (nije inicijalizovan)
# --------------------------------------------------
# Preporuka: Greška engine-a (nije inicijalizovan)
# --------------------------------------------------
# DEBUG [vrijeme_driver.py]: Initializing PyKE engine.
# DEBUG [vrijeme_driver.py]: Using source directory: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert
# DEBUG [vrijeme_driver.py]: Directory c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb already exists.
# DEBUG [vrijeme_driver.py]: Temporarily added to sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb
# DEBUG [vrijeme_driver.py]: Calling knowledge_engine.engine with search path: 'c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert'
# FATAL ERROR [vrijeme_driver.py]: Could not initialize PyKE engine: expected str, bytes or os.PathLike object, not NoneType
# Value and type of KB_DIRECTORY_PATH passed to engine was: 'c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert' (<class 'str'>)
# Traceback (most recent call last):
#   File "c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\vrijeme_driver.py", line 83, in initialize_engine_if_needed
#     engine = knowledge_engine.engine(KB_DIRECTORY_PATH)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\knowledge_engine.py", line 104, in __init__
#     self._create_target_pkg(path, target_pkgs)
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\knowledge_engine.py", line 215, in _create_target_pkg
#     tp = target_pkg.target_pkg(target_name, target_filename)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\target_pkg.py", line 102, in __init__
#     os.path.dirname(import_(self.package_name).__file__)
#   File "<frozen ntpath>", line 251, in dirname
#   File "<frozen ntpath>", line 213, in split
# TypeError: expected str, bytes or os.PathLike object, not NoneType
# DEBUG [vrijeme_driver.py]: Removed from sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb
# DEBUG [vrijeme_driver.py]: Initializing PyKE engine.
# DEBUG [vrijeme_driver.py]: Using source directory: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert
# DEBUG [vrijeme_driver.py]: Directory c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb already exists.
# DEBUG [vrijeme_driver.py]: Temporarily added to sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb
# DEBUG [vrijeme_driver.py]: Calling knowledge_engine.engine with search path: 'c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert'
# FATAL ERROR [vrijeme_driver.py]: Could not initialize PyKE engine: expected str, bytes or os.PathLike object, not NoneType
# Value and type of KB_DIRECTORY_PATH passed to engine was: 'c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert' (<class 'str'>)
# Traceback (most recent call last):
#   File "c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\vrijeme_driver.py", line 83, in initialize_engine_if_needed
#     engine = knowledge_engine.engine(KB_DIRECTORY_PATH)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\knowledge_engine.py", line 104, in __init__
#     self._create_target_pkg(path, target_pkgs)
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\knowledge_engine.py", line 215, in _create_target_pkg
#     tp = target_pkg.target_pkg(target_name, target_filename)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\target_pkg.py", line 102, in __init__
#     os.path.dirname(import_(self.package_name).__file__)
#   File "<frozen ntpath>", line 251, in dirname
#   File "<frozen ntpath>", line 213, in split
# TypeError: expected str, bytes or os.PathLike object, not NoneType
# DEBUG [vrijeme_driver.py]: Removed from sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb
# DEBUG [vrijeme_driver.py]: Initializing PyKE engine.
# DEBUG [vrijeme_driver.py]: Using source directory: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert
# DEBUG [vrijeme_driver.py]: Directory c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb already exists.
# DEBUG [vrijeme_driver.py]: Temporarily added to sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb
# DEBUG [vrijeme_driver.py]: Calling knowledge_engine.engine with search path: 'c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert'
# FATAL ERROR [vrijeme_driver.py]: Could not initialize PyKE engine: expected str, bytes or os.PathLike object, not NoneType
# Value and type of KB_DIRECTORY_PATH passed to engine was: 'c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert' (<class 'str'>)
# Traceback (most recent call last):
#   File "c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\vrijeme_driver.py", line 83, in initialize_engine_if_needed
#     engine = knowledge_engine.engine(KB_DIRECTORY_PATH)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\knowledge_engine.py", line 104, in __init__
#     self._create_target_pkg(path, target_pkgs)
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\knowledge_engine.py", line 215, in _create_target_pkg
#     tp = target_pkg.target_pkg(target_name, target_filename)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\target_pkg.py", line 102, in __init__
#     os.path.dirname(import_(self.package_name).__file__)
#   File "<frozen ntpath>", line 251, in dirname
#   File "<frozen ntpath>", line 213, in split
# TypeError: expected str, bytes or os.PathLike object, not NoneType
# DEBUG [vrijeme_driver.py]: Removed from sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb
# DEBUG [vrijeme_driver.py]: Initializing PyKE engine.
# DEBUG [vrijeme_driver.py]: Using source directory: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert
# DEBUG [vrijeme_driver.py]: Directory c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb already exists.
# DEBUG [vrijeme_driver.py]: Temporarily added to sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb
# DEBUG [vrijeme_driver.py]: Calling knowledge_engine.engine with search path: 'c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert'
# FATAL ERROR [vrijeme_driver.py]: Could not initialize PyKE engine: expected str, bytes or os.PathLike object, not NoneType
# Value and type of KB_DIRECTORY_PATH passed to engine was: 'c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert' (<class 'str'>)
# Traceback (most recent call last):
#   File "c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\vrijeme_driver.py", line 83, in initialize_engine_if_needed
#     engine = knowledge_engine.engine(KB_DIRECTORY_PATH)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\knowledge_engine.py", line 104, in __init__
#     self._create_target_pkg(path, target_pkgs)
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\knowledge_engine.py", line 215, in _create_target_pkg
#     tp = target_pkg.target_pkg(target_name, target_filename)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\pyke-1.1.1\pyke\target_pkg.py", line 102, in __init__
#     os.path.dirname(import_(self.package_name).__file__)
#   File "<frozen ntpath>", line 251, in dirname
#   File "<frozen ntpath>", line 213, in split
# TypeError: expected str, bytes or os.PathLike object, not NoneType
# DEBUG [vrijeme_driver.py]: Removed from sys.path: c:\Users\Benjo\Documents\GitHub\Artificial-Intelligence\Laboratory_Exercise_7\vremenski_ekspert\compiled_krb
